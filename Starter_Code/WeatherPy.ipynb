# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kirensk
# Processing Record 2 of Set 1 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 3 of Set 1 | puerto natales
# Processing Record 4 of Set 1 | aasiaat
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | waitangi
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | asan-maina village
# Processing Record 9 of Set 1 | la punta
# Processing Record 10 of Set 1 | ankazobe
# Processing Record 11 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 1 | papatowai
# Processing Record 13 of Set 1 | grytviken
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | ust-tsilma
# Processing Record 16 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 17 of Set 1 | lagoa
# Processing Record 18 of Set 1 | margate
# Processing Record 19 of Set 1 | isafjordur
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | margaret river
# Processing Record 22 of Set 1 | cabo san lucas
# Processing Record 23 of Set 1 | la ronge
# Processing Record 24 of Set 1 | geraldton
# Processing Record 25 of Set 1 | haiku-pauwela
# Processing Record 26 of Set 1 | dali
# Processing Record 27 of Set 1 | hamilton
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | badger
# Processing Record 30 of Set 1 | yigo village
# Processing Record 31 of Set 1 | tindouf
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | vorgashor
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | lushun
# Processing Record 36 of Set 1 | bardai
# Processing Record 37 of Set 1 | cody
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | kuala terengganu
# Processing Record 40 of Set 1 | blackmans bay
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | stanley
# Processing Record 43 of Set 1 | alice springs
# Processing Record 44 of Set 1 | ust-nera
# Processing Record 45 of Set 1 | anadyr
# Processing Record 46 of Set 1 | edinburgh of the seven seas
# Processing Record 47 of Set 1 | whitehorse
# Processing Record 48 of Set 1 | olonkinbyen
# Processing Record 49 of Set 1 | west island
# Processing Record 50 of Set 1 | valdivia
# Processing Record 0 of Set 2 | ta`u
# Processing Record 1 of Set 2 | kolondieba
# Processing Record 2 of Set 2 | satuba
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | ola
# Processing Record 5 of Set 2 | laguna
# Processing Record 6 of Set 2 | san patricio
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | karratha
# Processing Record 9 of Set 2 | chilecito
# Processing Record 10 of Set 2 | cape coast
# Processing Record 11 of Set 2 | vernon
# Processing Record 12 of Set 2 | st. john's
# Processing Record 13 of Set 2 | gadzhiyevo
# Processing Record 14 of Set 2 | ariquemes
# Processing Record 15 of Set 2 | taltal
# Processing Record 16 of Set 2 | annavasal
# Processing Record 17 of Set 2 | ixtapa
# Processing Record 18 of Set 2 | sinabang
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | turaif
# Processing Record 22 of Set 2 | brookings
# Processing Record 23 of Set 2 | bodaybo
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | invercargill
# Processing Record 26 of Set 2 | utrik
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | kharkhorin
# Processing Record 30 of Set 2 | bilibino
# Processing Record 31 of Set 2 | port mathurin
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | port saint john's
# Processing Record 34 of Set 2 | shalkar
# Processing Record 35 of Set 2 | tazovsky
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | south venice
# Processing Record 38 of Set 2 | richards bay
# Processing Record 39 of Set 2 | zrenjanin
# Processing Record 40 of Set 2 | victorica
# Processing Record 41 of Set 2 | aginskoye
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | tolanaro
# Processing Record 44 of Set 2 | el bauga
# Processing Record 45 of Set 2 | saipan
# Processing Record 46 of Set 2 | wick
# Processing Record 47 of Set 2 | lihue
# Processing Record 48 of Set 2 | nookat
# Processing Record 49 of Set 2 | aykhal
# Processing Record 0 of Set 3 | rouached
# Processing Record 1 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 2 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 3 of Set 3 | alamos
# Processing Record 4 of Set 3 | wolmaransstad
# Processing Record 5 of Set 3 | yanbu
# Processing Record 6 of Set 3 | suntar
# Processing Record 7 of Set 3 | bel ombre
# Processing Record 8 of Set 3 | sao vicente
# Processing Record 9 of Set 3 | chemolgan
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | moroni
# Processing Record 12 of Set 3 | yangambi
# Processing Record 13 of Set 3 | thunder bay
# Processing Record 14 of Set 3 | castillos
# Processing Record 15 of Set 3 | santana
# Processing Record 16 of Set 3 | brisas de zicatela
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | enewetak
# Processing Record 19 of Set 3 | nkwerre
# Processing Record 20 of Set 3 | parauapebas
# Processing Record 21 of Set 3 | mersa matruh
# Processing Record 22 of Set 3 | lagos
# Processing Record 23 of Set 3 | port douglas
# Processing Record 24 of Set 3 | santa branca
# Processing Record 25 of Set 3 | acapulco de juarez
# Processing Record 26 of Set 3 | gaigeturi
# Processing Record 27 of Set 3 | puerto aysen
# Processing Record 28 of Set 3 | juan griego
# Processing Record 29 of Set 3 | filey
# Processing Record 30 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 31 of Set 3 | mahina
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | wailua homesteads
# Processing Record 34 of Set 3 | fannuj
# City not found. Skipping...
# Processing Record 35 of Set 3 | nouadhibou
# Processing Record 36 of Set 3 | semporna
# Processing Record 37 of Set 3 | markovo
# Processing Record 38 of Set 3 | sabang
# Processing Record 39 of Set 3 | remire-montjoly
# Processing Record 40 of Set 3 | ceeldheer
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | tarinkot
# Processing Record 43 of Set 3 | tachilek
# City not found. Skipping...
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | eyl
# Processing Record 46 of Set 3 | beloyarskiy
# Processing Record 47 of Set 3 | salahonda
# Processing Record 48 of Set 3 | udachny
# Processing Record 49 of Set 3 | dauphin
# Processing Record 0 of Set 4 | college
# Processing Record 1 of Set 4 | keflavik
# Processing Record 2 of Set 4 | spinazzola
# Processing Record 3 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 4 of Set 4 | peace river
# Processing Record 5 of Set 4 | harstad
# Processing Record 6 of Set 4 | mugumu
# Processing Record 7 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 8 of Set 4 | tanki leendert
# City not found. Skipping...
# Processing Record 9 of Set 4 | imbituba
# Processing Record 10 of Set 4 | afaahiti
# Processing Record 11 of Set 4 | port alfred
# Processing Record 12 of Set 4 | weno
# Processing Record 13 of Set 4 | la passe
# Processing Record 14 of Set 4 | st. thomas
# Processing Record 15 of Set 4 | flying fish cove
# Processing Record 16 of Set 4 | taksimo
# Processing Record 17 of Set 4 | saldanha
# Processing Record 18 of Set 4 | hawaiian paradise park
# Processing Record 19 of Set 4 | carutapera
# Processing Record 20 of Set 4 | cidreira
# Processing Record 21 of Set 4 | nogliki
# Processing Record 22 of Set 4 | kasempa
# Processing Record 23 of Set 4 | touros
# Processing Record 24 of Set 4 | pico truncado
# Processing Record 25 of Set 4 | jamestown
# Processing Record 26 of Set 4 | tynda
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | saint-felicien
# Processing Record 29 of Set 4 | vientiane
# Processing Record 30 of Set 4 | dawson creek
# Processing Record 31 of Set 4 | dudinka
# Processing Record 32 of Set 4 | rio grande
# Processing Record 33 of Set 4 | gobabis
# Processing Record 34 of Set 4 | peachtree city
# Processing Record 35 of Set 4 | mandera
# Processing Record 36 of Set 4 | linqiong
# Processing Record 37 of Set 4 | bredasdorp
# Processing Record 38 of Set 4 | sitka
# Processing Record 39 of Set 4 | avarua
# Processing Record 40 of Set 4 | rio gallegos
# Processing Record 41 of Set 4 | malkinia gorna
# Processing Record 42 of Set 4 | lospalos
# Processing Record 43 of Set 4 | dolores
# Processing Record 44 of Set 4 | zaozersk
# Processing Record 45 of Set 4 | filadelfia
# Processing Record 46 of Set 4 | summerside
# Processing Record 47 of Set 4 | mirnyy
# Processing Record 48 of Set 4 | redencao
# Processing Record 49 of Set 4 | kodiak
# Processing Record 0 of Set 5 | el kef
# Processing Record 1 of Set 5 | toliara
# Processing Record 2 of Set 5 | kalmunai
# Processing Record 3 of Set 5 | mount isa
# Processing Record 4 of Set 5 | montepuez
# Processing Record 5 of Set 5 | timbuktu
# Processing Record 6 of Set 5 | bridgewater
# Processing Record 7 of Set 5 | igrim
# Processing Record 8 of Set 5 | pitimbu
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | dar naim
# City not found. Skipping...
# Processing Record 11 of Set 5 | novodvinsk
# Processing Record 12 of Set 5 | altamont
# Processing Record 13 of Set 5 | saarijarvi
# Processing Record 14 of Set 5 | mirny
# Processing Record 15 of Set 5 | praia da vitoria
# Processing Record 16 of Set 5 | hobyo
# Processing Record 17 of Set 5 | guerrero negro
# Processing Record 18 of Set 5 | sparta
# Processing Record 19 of Set 5 | tromso
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | port augusta
# Processing Record 22 of Set 5 | lazaro cardenas
# Processing Record 23 of Set 5 | puerto deseado
# Processing Record 24 of Set 5 | bocas del toro
# Processing Record 25 of Set 5 | vilyuchinsk
# Processing Record 26 of Set 5 | smithers
# Processing Record 27 of Set 5 | valvedditturai
# Processing Record 28 of Set 5 | borogontsy
# Processing Record 29 of Set 5 | rantauprapat
# Processing Record 30 of Set 5 | tadjourah
# Processing Record 31 of Set 5 | ilulissat
# Processing Record 32 of Set 5 | shimanovsk
# Processing Record 33 of Set 5 | amilly
# Processing Record 34 of Set 5 | guilin
# Processing Record 35 of Set 5 | al ghayzah
# Processing Record 36 of Set 5 | shortandy
# Processing Record 37 of Set 5 | los villares
# Processing Record 38 of Set 5 | galesong
# Processing Record 39 of Set 5 | yeniseysk
# Processing Record 40 of Set 5 | birao
# Processing Record 41 of Set 5 | forster
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | kalevala
# Processing Record 44 of Set 5 | nagercoil
# Processing Record 45 of Set 5 | lompoc
# Processing Record 46 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 47 of Set 5 | klaksvik
# Processing Record 48 of Set 5 | nabire
# Processing Record 49 of Set 5 | palikir - national government center
# Processing Record 0 of Set 6 | katsuura
# Processing Record 1 of Set 6 | spas-demensk
# Processing Record 2 of Set 6 | vysokiy
# Processing Record 3 of Set 6 | fort bragg
# Processing Record 4 of Set 6 | twon-brass
# Processing Record 5 of Set 6 | dzhalagash
# Processing Record 6 of Set 6 | hermanus
# Processing Record 7 of Set 6 | dahlonega
# Processing Record 8 of Set 6 | malabar
# Processing Record 9 of Set 6 | queenstown
# Processing Record 10 of Set 6 | we
# City not found. Skipping...
# Processing Record 11 of Set 6 | tura
# Processing Record 12 of Set 6 | porto novo
# Processing Record 13 of Set 6 | iskateley
# Processing Record 14 of Set 6 | barclayville
# Processing Record 15 of Set 6 | al kharijah
# Processing Record 16 of Set 6 | ouellah
# City not found. Skipping...
# Processing Record 17 of Set 6 | nago
# Processing Record 18 of Set 6 | boende
# Processing Record 19 of Set 6 | al bayda'
# Processing Record 20 of Set 6 | shenjiamen
# Processing Record 21 of Set 6 | belmonte
# Processing Record 22 of Set 6 | caleta de carquin
# Processing Record 23 of Set 6 | alofi
# Processing Record 24 of Set 6 | andergrove
# Processing Record 25 of Set 6 | naze
# Processing Record 26 of Set 6 | port hueneme
# Processing Record 27 of Set 6 | general mosconi
# Processing Record 28 of Set 6 | bilozerka
# Processing Record 29 of Set 6 | viana do castelo
# Processing Record 30 of Set 6 | ijuw
# City not found. Skipping...
# Processing Record 31 of Set 6 | coos bay
# Processing Record 32 of Set 6 | koh kong
# Processing Record 33 of Set 6 | seogwipo
# City not found. Skipping...
# Processing Record 34 of Set 6 | birnin kebbi
# Processing Record 35 of Set 6 | sajir
# Processing Record 36 of Set 6 | mejit
# Processing Record 37 of Set 6 | saguenay
# Processing Record 38 of Set 6 | acarau
# Processing Record 39 of Set 6 | benghazi
# Processing Record 40 of Set 6 | luis correia
# Processing Record 41 of Set 6 | hammerfest
# Processing Record 42 of Set 6 | al jawf
# Processing Record 43 of Set 6 | stornoway
# Processing Record 44 of Set 6 | ilabaya
# Processing Record 45 of Set 6 | cockburn town
# Processing Record 46 of Set 6 | talara
# Processing Record 47 of Set 6 | prado
# Processing Record 48 of Set 6 | chinde
# Processing Record 49 of Set 6 | muynoq
# Processing Record 0 of Set 7 | snihurivka
# Processing Record 1 of Set 7 | sierra vista
# Processing Record 2 of Set 7 | wenling
# Processing Record 3 of Set 7 | puerto yuca
# Processing Record 4 of Set 7 | constantia
# Processing Record 5 of Set 7 | sidi amrane
# Processing Record 6 of Set 7 | hadibu
# Processing Record 7 of Set 7 | pangai
# Processing Record 8 of Set 7 | chililabombwe
# Processing Record 9 of Set 7 | goba
# Processing Record 10 of Set 7 | parczew
# Processing Record 11 of Set 7 | hoi an
# Processing Record 12 of Set 7 | shalqar
# Processing Record 13 of Set 7 | chimore
# Processing Record 14 of Set 7 | egilsstadir
# Processing Record 15 of Set 7 | port hedland
# Processing Record 16 of Set 7 | lindale
# Processing Record 17 of Set 7 | kilindoni
# Processing Record 18 of Set 7 | labasa
# Processing Record 19 of Set 7 | jayapura
# Processing Record 20 of Set 7 | buka
# Processing Record 21 of Set 7 | kerikeri
# Processing Record 22 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 23 of Set 7 | qamdo
# Processing Record 24 of Set 7 | north bend
# Processing Record 25 of Set 7 | calvinia
# Processing Record 26 of Set 7 | mata-utu
# Processing Record 27 of Set 7 | sarakhs
# Processing Record 28 of Set 7 | chernyshevsk
# Processing Record 29 of Set 7 | garachico
# Processing Record 30 of Set 7 | palmer
# Processing Record 31 of Set 7 | yuzhno-kurilsk
# Processing Record 32 of Set 7 | astara
# Processing Record 33 of Set 7 | villa gesell
# Processing Record 34 of Set 7 | coquimbo
# Processing Record 35 of Set 7 | iwon-up
# Processing Record 36 of Set 7 | tissemsilt
# Processing Record 37 of Set 7 | chegdomyn
# Processing Record 38 of Set 7 | fortaleza
# Processing Record 39 of Set 7 | kertih
# Processing Record 40 of Set 7 | novotroitskaya
# Processing Record 41 of Set 7 | kingston
# Processing Record 42 of Set 7 | santa ana
# Processing Record 43 of Set 7 | sandnessjoen
# Processing Record 44 of Set 7 | mutoko
# Processing Record 45 of Set 7 | candelaria
# Processing Record 46 of Set 7 | minot air force base
# Processing Record 47 of Set 7 | mimizan
# Processing Record 48 of Set 7 | ambanja
# Processing Record 49 of Set 7 | praia
# Processing Record 0 of Set 8 | biltine
# Processing Record 1 of Set 8 | vryburg
# Processing Record 2 of Set 8 | qui nhon
# Processing Record 3 of Set 8 | xai-xai
# Processing Record 4 of Set 8 | nova vicosa
# Processing Record 5 of Set 8 | tidjikja
# Processing Record 6 of Set 8 | eraan
# Processing Record 7 of Set 8 | howrah
# Processing Record 8 of Set 8 | xixiang
# Processing Record 9 of Set 8 | kattivakkam
# Processing Record 10 of Set 8 | livingston
# Processing Record 11 of Set 8 | nueva gerona
# Processing Record 12 of Set 8 | magistral'nyy
# Processing Record 13 of Set 8 | caconda
# Processing Record 14 of Set 8 | khandud
# Processing Record 15 of Set 8 | kaa-khem
# Processing Record 16 of Set 8 | pasni
# Processing Record 17 of Set 8 | salinopolis
# Processing Record 18 of Set 8 | al jumum
# Processing Record 19 of Set 8 | lorengau
# Processing Record 20 of Set 8 | itoman
# Processing Record 21 of Set 8 | mount pearl
# Processing Record 22 of Set 8 | peterhead
# Processing Record 23 of Set 8 | dong ha
# Processing Record 24 of Set 8 | macapa
# Processing Record 25 of Set 8 | thabazimbi
# Processing Record 26 of Set 8 | moab
# Processing Record 27 of Set 8 | nadym
# Processing Record 28 of Set 8 | san mateo del mar
# Processing Record 29 of Set 8 | alaghsas
# Processing Record 30 of Set 8 | steyr
# Processing Record 31 of Set 8 | aparan
# Processing Record 32 of Set 8 | happy valley-goose bay
# Processing Record 33 of Set 8 | sabzevar
# Processing Record 34 of Set 8 | quellon
# Processing Record 35 of Set 8 | caetite
# Processing Record 36 of Set 8 | general acha
# Processing Record 37 of Set 8 | crane
# Processing Record 38 of Set 8 | fale old settlement
# Processing Record 39 of Set 8 | proletarskiy
# Processing Record 40 of Set 8 | freetown
# Processing Record 41 of Set 8 | dabai
# Processing Record 42 of Set 8 | presidente dutra
# Processing Record 43 of Set 8 | kuzhener
# Processing Record 44 of Set 8 | robore
# Processing Record 45 of Set 8 | fabens
# Processing Record 46 of Set 8 | kargasok
# Processing Record 47 of Set 8 | kaiama
# Processing Record 48 of Set 8 | khandyga
# Processing Record 49 of Set 8 | huadian
# Processing Record 0 of Set 9 | nortelandia
# Processing Record 1 of Set 9 | port lincoln
# Processing Record 2 of Set 9 | bejaia
# Processing Record 3 of Set 9 | esquel
# Processing Record 4 of Set 9 | virginia
# Processing Record 5 of Set 9 | charleston
# Processing Record 6 of Set 9 | canlaon
# Processing Record 7 of Set 9 | mablethorpe
# City not found. Skipping...
# Processing Record 8 of Set 9 | bacalar
# Processing Record 9 of Set 9 | canton
# Processing Record 10 of Set 9 | bikenibeu village
# Processing Record 11 of Set 9 | chonchi
# Processing Record 12 of Set 9 | faya-largeau
# Processing Record 13 of Set 9 | lerwick
# Processing Record 14 of Set 9 | shahrak
# Processing Record 15 of Set 9 | astrakhan
# Processing Record 16 of Set 9 | chelm
# Processing Record 17 of Set 9 | forbes
# Processing Record 18 of Set 9 | collinsville
# Processing Record 19 of Set 9 | hirara
# Processing Record 20 of Set 9 | tazacorte
# Processing Record 21 of Set 9 | port moresby
# Processing Record 22 of Set 9 | mwaro
# Processing Record 23 of Set 9 | butare
# Processing Record 24 of Set 9 | oualidia
# City not found. Skipping...
# Processing Record 25 of Set 9 | san pedro
# Processing Record 26 of Set 9 | pelaya
# Processing Record 27 of Set 9 | nuuk
# Processing Record 28 of Set 9 | jagna
# Processing Record 29 of Set 9 | sentjur
# Processing Record 30 of Set 9 | simpang
# Processing Record 31 of Set 9 | melfort
# Processing Record 32 of Set 9 | posse
# Processing Record 33 of Set 9 | sao joao de pirabas
# Processing Record 34 of Set 9 | taoudenni
# Processing Record 35 of Set 9 | kenai
# Processing Record 36 of Set 9 | cole harbour
# Processing Record 37 of Set 9 | sungai penuh
# Processing Record 38 of Set 9 | polyarnyy
# Processing Record 39 of Set 9 | saratamata
# City not found. Skipping...
# Processing Record 40 of Set 9 | vilyuysk
# Processing Record 41 of Set 9 | zouerate
# Processing Record 42 of Set 9 | kidal
# Processing Record 43 of Set 9 | mehekar
# Processing Record 44 of Set 9 | douvres-la-delivrande
# Processing Record 45 of Set 9 | telimele
# Processing Record 46 of Set 9 | nova sintra
# Processing Record 47 of Set 9 | dongola
# Processing Record 48 of Set 9 | kapuskasing
# Processing Record 49 of Set 9 | narrabri
# Processing Record 0 of Set 10 | shingu
# Processing Record 1 of Set 10 | saksaul'skiy
# City not found. Skipping...
# Processing Record 2 of Set 10 | tobi village
# City not found. Skipping...
# Processing Record 3 of Set 10 | klyuchi
# Processing Record 4 of Set 10 | namibe
# Processing Record 5 of Set 10 | ulladulla
# Processing Record 6 of Set 10 | marco island
# Processing Record 7 of Set 10 | ulaangom
# Processing Record 8 of Set 10 | leskovac
# Processing Record 9 of Set 10 | nemuro
# Processing Record 10 of Set 10 | pandan
# Processing Record 11 of Set 10 | broken hill
# Processing Record 12 of Set 10 | pierre
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | taroa
# Processing Record 15 of Set 10 | ancud
# Processing Record 16 of Set 10 | manggar
# Processing Record 17 of Set 10 | surab
# Processing Record 18 of Set 10 | bapatla
# Processing Record 19 of Set 10 | myanaung
# Processing Record 20 of Set 10 | kultali
# City not found. Skipping...
# Processing Record 21 of Set 10 | frenda
# Processing Record 22 of Set 10 | christchurch
# Processing Record 23 of Set 10 | kloulklubed
# Processing Record 24 of Set 10 | tyukhtet
# Processing Record 25 of Set 10 | autazes
# Processing Record 26 of Set 10 | terrace
# Processing Record 27 of Set 10 | esquina
# Processing Record 28 of Set 10 | wahpeton
# Processing Record 29 of Set 10 | reggane
# Processing Record 30 of Set 10 | qaqortoq
# Processing Record 31 of Set 10 | aldan
# Processing Record 32 of Set 10 | vanimo
# Processing Record 33 of Set 10 | vadso
# Processing Record 34 of Set 10 | ad dabbah
# Processing Record 35 of Set 10 | pundong
# Processing Record 36 of Set 10 | tabou
# Processing Record 37 of Set 10 | alvaraes
# Processing Record 38 of Set 10 | poxoreo
# Processing Record 39 of Set 10 | ji'an
# Processing Record 40 of Set 10 | sola
# Processing Record 41 of Set 10 | alotau
# Processing Record 42 of Set 10 | antofagasta
# Processing Record 43 of Set 10 | vecindario
# City not found. Skipping...
# Processing Record 44 of Set 10 | yinchuan
# Processing Record 45 of Set 10 | ban houakhoua
# Processing Record 46 of Set 10 | san antonio de pale
# Processing Record 47 of Set 10 | coxim
# Processing Record 48 of Set 10 | kirando
# Processing Record 49 of Set 10 | aripuana
# Processing Record 0 of Set 11 | hawick
# Processing Record 1 of Set 11 | illizi
# Processing Record 2 of Set 11 | buala
# Processing Record 3 of Set 11 | port blair
# Processing Record 4 of Set 11 | hasaki
# Processing Record 5 of Set 11 | rumonge
# Processing Record 6 of Set 11 | uyuni
# Processing Record 7 of Set 11 | playa del ingles
# Processing Record 8 of Set 11 | kone
# Processing Record 9 of Set 11 | mutum biyu
# Processing Record 10 of Set 11 | ceres
# Processing Record 11 of Set 11 | san agustin de valle fertil
# Processing Record 12 of Set 11 | souk ahras
# Processing Record 13 of Set 11 | rawai
# Processing Record 14 of Set 11 | port-gentil
# Processing Record 15 of Set 11 | cill airne
# Processing Record 16 of Set 11 | nuku'alofa
# Processing Record 17 of Set 11 | montevideo
# Processing Record 18 of Set 11 | atafu village
# Processing Record 19 of Set 11 | xilin hot
# Processing Record 20 of Set 11 | altai
# Processing Record 21 of Set 11 | tanah rata
# Processing Record 22 of Set 11 | manta
# Processing Record 23 of Set 11 | igbeti
# Processing Record 24 of Set 11 | elliot lake
# Processing Record 25 of Set 11 | yaren
# Processing Record 26 of Set 11 | lhuentse
# Processing Record 27 of Set 11 | lobujya
# Processing Record 28 of Set 11 | vetluga
# Processing Record 29 of Set 11 | portland
# Processing Record 30 of Set 11 | nha trang
# Processing Record 31 of Set 11 | baardheere
# Processing Record 32 of Set 11 | souillac
# Processing Record 33 of Set 11 | plastun
# Processing Record 34 of Set 11 | deland
# Processing Record 35 of Set 11 | waterford
# Processing Record 36 of Set 11 | cotacachi
# Processing Record 37 of Set 11 | sharypovo
# Processing Record 38 of Set 11 | mogadishu
# Processing Record 39 of Set 11 | kambove
# Processing Record 40 of Set 11 | robit
# Processing Record 41 of Set 11 | okene
# Processing Record 42 of Set 11 | corcoran
# Processing Record 43 of Set 11 | okhotsk
# Processing Record 44 of Set 11 | gediz
# Processing Record 45 of Set 11 | ribeira brava
# Processing Record 46 of Set 11 | nantucket
# Processing Record 47 of Set 11 | deming
# Processing Record 48 of Set 11 | pokrov
# Processing Record 49 of Set 11 | pangody
# Processing Record 0 of Set 12 | verkhnyaya salda
# Processing Record 1 of Set 12 | sosnogorsk
# Processing Record 2 of Set 12 | sohar
# Processing Record 3 of Set 12 | amos
# Processing Record 4 of Set 12 | pahrump
# Processing Record 5 of Set 12 | al-`ula
# City not found. Skipping...
# Processing Record 6 of Set 12 | ingeniero guillermo n. juarez
# Processing Record 7 of Set 12 | alajarvi
# Processing Record 8 of Set 12 | goulburn
# Processing Record 9 of Set 12 | neryungri
# Processing Record 10 of Set 12 | bu'aale
# Processing Record 11 of Set 12 | leava
# Processing Record 12 of Set 12 | ellsworth
# Processing Record 13 of Set 12 | nenjiang
# Processing Record 14 of Set 12 | lawton
# Processing Record 15 of Set 12 | barra do bugres
# Processing Record 16 of Set 12 | santa marta
# Processing Record 17 of Set 12 | kangding
# Processing Record 18 of Set 12 | kailua-kona
# Processing Record 19 of Set 12 | dryden
# Processing Record 20 of Set 12 | dolinsk
# Processing Record 21 of Set 12 | ghat
# Processing Record 22 of Set 12 | lautoka
# Processing Record 23 of Set 12 | verkhnevilyuysk
# Processing Record 24 of Set 12 | midvagur
# Processing Record 25 of Set 12 | berdigestyakh
# Processing Record 26 of Set 12 | ilha de mocambique
# Processing Record 27 of Set 12 | luau
# Processing Record 28 of Set 12 | shahritus
# Processing Record 29 of Set 12 | taunggyi
# Processing Record 30 of Set 12 | kutum
# Processing Record 31 of Set 12 | rapar
# Processing Record 32 of Set 12 | santiago de tolu
# Processing Record 33 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 34 of Set 12 | banda aceh
# Processing Record 35 of Set 12 | nueva esperanza
# Processing Record 36 of Set 12 | ndungu
# Processing Record 37 of Set 12 | raton
# Processing Record 38 of Set 12 | umm kaddadah
# Processing Record 39 of Set 12 | tralee
# Processing Record 40 of Set 12 | yashikira
# Processing Record 41 of Set 12 | cananea
# Processing Record 42 of Set 12 | kavaratti
# Processing Record 43 of Set 12 | spanish springs
# Processing Record 44 of Set 12 | gornyye klyuchi
# Processing Record 45 of Set 12 | kingscliff
# Processing Record 46 of Set 12 | vorkuta
# Processing Record 47 of Set 12 | bandarbeyla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         kirensk  57.7853  108.1119    258.28        87          79
# 1  puerto natales -51.7236  -72.4875    279.09        75         100
# 2         aasiaat  68.7098  -52.8699    257.92        87          52
# 3         ushuaia -54.8000  -68.3000    275.71        97         100
# 4        waitangi -43.9535 -176.5597    289.16        97         100
#
#    Wind Speed Country        Date
# 0        3.89      RU  1733728138
# 1        1.42      CL  1733728141
# 2        3.09      GL  1733728142
# 3        2.64      AR  1733728143
# 4        3.58      NZ  1733728144

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities1.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities1.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               kirensk  57.7853  108.1119    258.28        87          79
# 1        puerto natales -51.7236  -72.4875    279.09        75         100
# 2               aasiaat  68.7098  -52.8699    257.92        87          52
# 3               ushuaia -54.8000  -68.3000    275.71        97         100
# 4              waitangi -43.9535 -176.5597    289.16        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.89      RU  1733728138
# 1              1.42      CL  1733728141
# 2              3.09      GL  1733728142
# 3              2.64      AR  1733728143
# 4              3.58      NZ  1733728144

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)
                                                                   

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%Y-%m-%d"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):

    #compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) =linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    #plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    text_coordinates = (min(x_values),max(y_values) -10)
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(F"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   kirensk  57.7853  108.1119    258.28        87
# 2                   aasiaat  68.7098  -52.8699    257.92        87
# 6        asan-maina village  13.4722  144.7165    302.11        77
# 11                  iqaluit  63.7506  -68.5145    252.42        70
# 12               ust-tsilma  65.4410   52.1498    265.00        95
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                79        3.89      RU  1733728138
# 2                52        3.09      GL  1733728142
# 6                40        3.60      GU  1733728146
# 11               99        8.94      CA  1733728004
# 12              100        2.76      RU  1733728153

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        puerto natales -51.7236  -72.4875    279.09        75         100
# 3               ushuaia -54.8000  -68.3000    275.71        97         100
# 4              waitangi -43.9535 -176.5597    289.16        97         100
# 5             adamstown -25.0660 -130.1015    295.94        74           1
# 7              la punta -33.1837  -66.3127    288.55        60          47
#
#          Wind Speed Country        Date
# City_ID
# 1              1.42      CL  1733728141
# 3              2.64      AR  1733728143
# 4              3.58      NZ  1733728144
# 5              8.83      PN  1733728145
# 7              6.88      AR  1733728147

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10))
# Out:
# The r-value is: 0.7563147140693983

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55,35))
# Out:
# The r-value is: 0.4486007854609619

# %% [markdown]
# **Discussion about the linear relationship:** A high r value indicates a strong positive correlation between latitude and max temperature. R values > 0.5 indicate that there is a moderate positive correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (40,10))
# Out:
# The r-value is: 0.1968540983914587

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-50,20))
# Out:
# The r-value is: 0.026633071912699945

# %% [markdown]
# **Discussion about the linear relationship:** The r values are low this indicates a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40,10))
# Out:
# The r-value is: 0.0673327584762126

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40,10))
# Out:
# The r-value is: 0.00570820588410319

# %% [markdown]
# **Discussion about the linear relationship:** The r values are low, this indicates a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10,12))
# Out:
# The r-value is: 0.0013589276672841045

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50,12))
# Out:
# The r-value is: 0.02089245842764333

# %% [markdown]
# **Discussion about the linear relationship:** The r values are low, this indicates that there is no real relationship between wind speed and latitude.
